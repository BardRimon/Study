# %% [markdown]
# <a href="https://colab.research.google.com/github/BardRimon/Study/blob/main/CV/PRACTICE_№1_classification_training.ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Обучение CNN классификатора

# %% [markdown]
# https://www.kaggle.com/datasets/asaniczka/pc-parts-images-dataset-classification - датасет

# %%
import kagglehub
import os
# Download latest version
datapath = kagglehub.dataset_download("asaniczka/pc-parts-images-dataset-classification") + '/pc_parts'
print("Path to dataset files:", datapath)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts

# %%
os.listdir(datapath), len(os.listdir(datapath))
# Out:
# (['hdd',
#   'headset',
#   'cables',
#   'mouse',
#   'speakers',
#   'webcam',
#   'motherboard',
#   'monitor',
#   'cpu',
#   'keyboard',
#   'ram',
#   'gpu',
#   'case',
#   'microphone'],
#  14)

# %%
import torch
import torch.nn as nn
import torchvision.transforms.v2 as transforms
from torch.utils.data import DataLoader
import torch.optim as optim

from tqdm import tqdm
import random
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
from PIL import Image

# %matplotlib inline
# Установка стилистики графиков
plt.style.use('ggplot')

# %%
# Установка Seed для воспроизводимости
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Создадим датасет:

# %% [markdown]
# `torch.utils.data.Dataset` - абстрактный класс, от которого необходимо наследоваться для реализации своего датасета.
#
# **Методы для перезаписывания:**
# - `__init__` - конструктор, необязательно прописывать, но является удобным и скорее правильным способом загрузки базовых данных.
# - `__getitem__` - обязательный метод, принимает в себя аргумент index (индекс в данных). Должен возвращать данные, которые находятся по заданному индексу. Для задачи классификации - это изображение и метка класса, для задачи детекции - изображение и bounding box, для сегментации - изображение и маска.
# - `__len__` - опциональный метод, но если необходимо использовать Dataloader'ы - то обязательный. Должен возвращать кол-во объектов в датасете, по сути, нужен, чтобы Dataloader мог вести корректную индексацию по датасету и не выходить за границы выборки.
# - `__getitems__` - опциональный метод, принимает в себя список индексов в данных (indices). Должен возвращать список объектов по заданным индексам. Формат объектов такой же, как в `__getitem__`. Можно использовать, чтобы Dataloader получал сразу несколько элементов, что в некоторых случаях будет быстрее - так как будет возможность применять препроцессинг и аугментации сразу ко всем тензору, а не по отдельности.

# %% [markdown]
# **Описание абстрактного класса Dataset от Pytorch:**
#
# An abstract class representing a :class:`Dataset`.
#
# All datasets that represent a map from keys to data samples should subclass
# it. All subclasses should overwrite :meth:`__getitem__`, supporting fetching a
# data sample for a given key. Subclasses could also optionally overwrite
# :meth:`__len__`, which is expected to return the size of the dataset by many
# :class:`~torch.utils.data.Sampler` implementations and the default options
# of :class:`~torch.utils.data.DataLoader`. Subclasses could also
# optionally implement :meth:`__getitems__`, for speedup batched samples
# loading. This method accepts list of indices of samples of batch and returns
# list of samples.
#
# .. note::
#     :class:`~torch.utils.data.DataLoader` by default constructs an index
#     sampler that yields integral indices.  To make it work with a map-style
#     dataset with non-integral indices/keys, a custom sampler must be provided.

# %%
import os
from torch.utils.data import Dataset
from torchvision.io import decode_image, ImageReadMode
import functools

# %%
class DatasetPC(Dataset):
    @functools.cache
    @staticmethod
    def list_data_dir(root_dir):
        """
        Чтение данных из папки  только пути к файлам и метки классам. Сами изображения подгружаем в __getitem__.

        :return:
        1. Список, где каждый элемент - это кортеж (путь к файлу и метка класса).
        2. Список классов
        """
        # os.listdir(data_dir) - выдает названия всех файлов и папок внутри заданной папки data_dir
        # os.path.join(path1, path2) - соединяет строки, как пути, то есть результатом тут будет path1\path2
        data = []
        for label_index, label in enumerate(os.listdir(root_dir)):
            label_dir = os.path.join(root_dir, label)
            for filename in os.listdir(label_dir):
                filepath = os.path.join(label_dir, filename)
                data.append((filepath, label_index))

        return data, os.listdir(root_dir)

    @staticmethod
    def data_split(data, split_ratio):
        """
        Разделение списка данных на тренировочные и валидационные данные с сохранением пропорций классов.

        :return: Два списка: тренировочный и валидационный.
        """
        # Группируем данные по классам в словарь в формате (метка класса: список файлов)
        label_dict = {}
        for filepath, label in data:
            if label in label_dict:
                label_dict[label].append(filepath)
            else:
                label_dict[label] = [filepath]

        # Проходимся по всем группам (меткам класса) и делим на тренировочную и тестовую
        train_data = []
        valid_data = []
        for label, filepaths in label_dict.items():
            train_size = int(len(filepaths) * split_ratio)
            label_data = [(filepath, label) for filepath in filepaths]
            train_data.extend(label_data[:train_size])
            valid_data.extend(label_data[train_size:])

        return train_data, valid_data


    def __init__(self, root_dir, train=True, transform=None, split_ratio=0.8):
        """
        Инициализация класса DatasetPC.

        :param root_dir: Путь к директории с изображениями.
        :param train: Флаг, указывающий, является ли датасет тренировочным.
        :param transform: Трансформации, применяемые к изображениям.
        :param split_ratio: Доля данных, используемая для тренировки.
        """
        self.data, self.classes = DatasetPC.list_data_dir(root_dir) # Записываем данные из папки (пути к файлам и классы)
        train_data, valid_data = DatasetPC.data_split(self.data, split_ratio) # Разделяем на тренировочную и валидационную выборки
        self.data = train_data if train else valid_data # Выбираем какую выборку взять тренировочную или тестовую
        self.transform = transform # Записываем функцию для трансформации изображения


    def __len__(self):
        """
        Возвращает количество изображений в датасете.

        :return: Количество изображений.
        """
        return len(self.data)


    def __getitem__(self, index):
        """
        Возвращает изображение и метку по индексу.

        :param index: Индекс изображения.
        :return: Изображение и метка класса.
        """

        image_path, label = self.data[index]

        # from torchvision.io import decode_image, ImageReadMode
        image = decode_image(image_path, mode=ImageReadMode.RGB)
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
data, classes = DatasetPC.list_data_dir(datapath)
data[10:20], data[1000:1010], data[-10:]
# Out:
# ([('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/241.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/113.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/180.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/2.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/237.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/190.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/130.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/257.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/234.jpg',
#    0),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/32.jpg',
#    0)],
#  [('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/41.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/171.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/148.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/170.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/119.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/107.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/114.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/155.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/60.jpg',
#    3),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/mouse/21.jpg',
#    3)],
#  [('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/74.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/27.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/182.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/121.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/88.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/22.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/117.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/166.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/175.jpg',
#    13),
#   ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/microphone/57.jpg',
#    13)])

# %%
train_data, valid_data = DatasetPC.data_split(data, 0.8)

train_data
# Out:
# [('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/253.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/37.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/193.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/16.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/38.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/246.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/143.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/97.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/24.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/87.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/241.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/113.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/180.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/2.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/237.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/190.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/130.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/257.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/234.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/32.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/245.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/192.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/44.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/35.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/203.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/179.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/236.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/200.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/42.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/242.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/153.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/90.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/232.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/79.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/7.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/207.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/157.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/94.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/205.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/11.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/46.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/172.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/161.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/28.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/251.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/222.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/141.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/89.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/108.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/256.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/124.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/244.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/13.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/103.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/8.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/15.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/131.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/243.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/187.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/76.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/248.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/178.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/137.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/66.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/163.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/149.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/255.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/218.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/139.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/183.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/64.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/219.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/19.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/156.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/159.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/68.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/14.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/209.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/109.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/184.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/254.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/92.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/23.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/176.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/84.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/73.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/125.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/52.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/39.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/115.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/142.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/128.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/85.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/239.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/210.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/132.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/146.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/81.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/196.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/26.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/3.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/45.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/47.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/75.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/140.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/240.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/238.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/78.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/186.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/86.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/10.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/177.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/50.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/228.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/63.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/70.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/118.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/138.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/77.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/9.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/62.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/224.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/154.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/258.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/59.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/220.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/199.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/48.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/261.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/58.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/174.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/36.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/202.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/102.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/83.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/249.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/123.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/4.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/216.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/188.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/235.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/127.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/91.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/112.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/185.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/65.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/259.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/12.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/6.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/98.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/61.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/49.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/33.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/17.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/233.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/134.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/116.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/144.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/25.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/136.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/95.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/69.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/104.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/80.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/247.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/82.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/152.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/201.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/167.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/105.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/198.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/100.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/34.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/221.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/227.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/20.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/160.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/158.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/204.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/5.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/56.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/162.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/229.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/223.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/101.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/31.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/72.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/67.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/29.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/260.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/252.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/211.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/96.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/213.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/208.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/120.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/164.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/126.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/230.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/194.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/225.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/173.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/168.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/191.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/147.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/129.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/18.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/93.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/hdd/51.jpg',
#   0),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/253.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/37.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/193.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/16.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/38.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/246.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/143.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/97.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/24.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/87.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/241.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/113.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/180.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/2.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/237.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/190.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/130.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/257.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/234.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/32.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/245.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/192.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/44.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/35.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/203.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/179.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/236.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/200.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/42.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/242.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/153.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/90.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/232.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/79.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/7.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/207.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/157.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/94.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/205.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/11.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/46.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/172.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/161.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/28.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/251.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/222.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/141.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/89.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/108.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/256.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/124.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/244.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/13.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/103.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/8.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/15.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/131.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/243.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/187.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/76.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/248.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/178.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/137.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/66.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/163.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/149.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/255.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/218.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/139.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/183.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/64.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/219.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/19.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/156.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/159.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/68.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/14.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/209.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/109.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/184.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/254.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/92.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/23.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/176.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/84.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/73.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/125.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/52.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/39.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/115.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/142.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/128.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/85.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/239.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/210.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/132.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/146.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/81.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/196.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/26.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/3.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/45.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/47.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/75.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/140.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/240.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/238.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/78.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/186.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/86.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/10.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/177.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/50.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/228.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/63.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/70.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/118.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/138.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/77.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/9.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/62.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/224.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/154.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/258.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/59.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/220.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/199.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/48.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/261.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/58.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/174.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/36.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/202.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/102.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/83.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/249.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/123.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/4.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/216.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/188.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/235.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/127.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/91.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/112.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/185.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/65.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/259.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/12.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/6.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/98.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/61.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/49.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/33.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/17.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/233.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/134.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/116.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/144.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/25.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/136.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/95.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/69.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/104.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/80.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/247.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/82.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/152.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/201.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/167.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/105.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/198.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/100.jpg',
#   1),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/headset/34.jpg',
#   1),
# ...
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/108.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/256.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/124.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/244.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/13.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/103.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/8.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/273.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/15.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/131.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/243.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/187.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/76.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/248.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/178.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/137.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/66.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/282.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/163.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/292.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/149.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/255.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/218.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/139.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/183.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/275.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/64.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/219.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/267.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/265.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/19.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/156.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/159.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/68.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/14.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/209.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/109.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/184.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/254.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/92.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/23.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/176.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/84.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/73.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/125.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/52.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/39.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/115.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/142.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/128.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/296.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/85.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/239.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/210.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/132.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/146.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/81.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/196.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/26.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/3.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/45.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/47.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/75.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/140.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/240.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/238.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/78.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/186.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/86.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/10.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/177.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/50.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/228.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/288.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/63.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/266.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/70.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/295.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/118.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/138.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/77.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/9.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/271.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/62.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/224.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/154.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/258.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/59.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/220.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/199.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/48.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/261.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/58.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/174.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/36.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/202.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/102.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/270.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/83.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/249.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/123.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/4.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/216.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/188.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/235.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/127.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/91.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/112.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/185.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/65.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/259.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/12.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/6.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/98.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/61.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/277.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/49.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/33.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/268.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/17.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/269.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/233.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/134.jpg',
#   4),
#  ('/root/.cache/kagglehub/datasets/asaniczka/pc-parts-images-dataset-classification/versions/1/pc_parts/speakers/116.jpg',
#   4),
#  ...]

# %%
len(train_data), len(valid_data), len(train_data) / len(valid_data)
# Out:
# (2616, 663, 3.9457013574660635)

# %%
from torch.utils.data import Dataset, random_split
from torchvision.datasets import ImageFolder

class DatasetPC(Dataset):
    def __init__(self, root_dir, train=True, transform=None, split_ratio=0.8, seed=42):
        """
        Инициализация класса DatasetPC.

        :param root_dir: Путь к директории с изображениями.
        :param train: Флаг, указывающий, является ли датасет тренировочным.
        :param transform: Трансформации, применяемые к изображениям.
        :param split_ratio: Доля данных, используемая для тренировки.
        :param seed: Значение seed для фиксации случайности.
        """
        self.root_dir = root_dir
        self.train = train
        self.transform = transform
        self.split_ratio = split_ratio
        self.seed = seed
        self.transform = transform

        # Загрузка всех изображений
        self.full_dataset = ImageFolder(root_dir, transform=None)
        self.classes = self.full_dataset.classes
        self.class_to_idx = self.full_dataset.class_to_idx

        # Разделение датасета на тренировочные и валидационные данные с сохранением пропорций классов
        self.train_dataset, self.val_dataset = self._split_dataset()
        self.dataset = self.train_dataset if self.train else self.val_dataset

    def _split_dataset(self):
        """
        Разделение датасета на тренировочные и валидационные данные с сохранением пропорций классов.

        :return: Два датасета: тренировочный и валидационный.
        """
        # Фиксация seed для воспроизводимости
        torch.manual_seed(self.seed)

        # Подсчет количества образцов для каждого класса
        class_counts = {cls: 0 for cls in self.classes}
        for _, label in self.full_dataset:
            class_counts[self.classes[label]] += 1

        # Расчет количества образцов для тренировки и валидации для каждого класса
        train_counts = {cls: int(self.split_ratio * count) for cls, count in class_counts.items()}
        val_counts = {cls: count - train_counts[cls] for cls, count in class_counts.items()}

        # Разделение датасета для каждого класса
        train_dataset, val_dataset = [], []
        for cls in self.classes:
            cls_indices = [i for i, (_, label) in enumerate(self.full_dataset) if self.classes[label] == cls]
            cls_train_indices, cls_val_indices = random_split(cls_indices, [train_counts[cls], val_counts[cls]])
            train_dataset.extend([self.full_dataset[i] for i in cls_train_indices])
            val_dataset.extend([self.full_dataset[i] for i in cls_val_indices])

        return train_dataset, val_dataset

    def __len__(self):
        """
        Возвращает количество изображений в датасете.

        :return: Количество изображений.
        """
        return len(self.dataset)

    def __getitem__(self, idx):
        """
        Возвращает изображение и метку по индексу.

        :param idx: Индекс изображения.
        :return: Изображение и метка.
        """
        image, label = self.dataset[idx]
        image = torch.from_numpy(np.array(image)).permute(2,0,1)
        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# # Без особых аугментаций

# %%
dir(Dataset)
# Out:
# ['__add__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
# Определим пути к данным

# Определим трансформации
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Создадим датасеты
train_dataset = DatasetPC(datapath, train=True, transform=train_transforms)
val_dataset = DatasetPC(datapath, train=False, transform=val_transforms)

# Создадим датагенераторы
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Список классов:

# %%
classes_list = train_dataset.classes
print(classes_list)
# Out:
# ['cables', 'case', 'cpu', 'gpu', 'hdd', 'headset', 'keyboard', 'microphone', 'monitor', 'motherboard', 'mouse', 'ram', 'speakers', 'webcam']

# %%
# Подсчитать количество изображений в каждом классе для обучающего набора данных
train_class_counts = np.zeros(len(train_dataset.classes))
for _, label in train_dataset:
    train_class_counts[label] += 1

# Подсчитать количество изображений в каждом классе для валидационного набора данных
val_class_counts = np.zeros(len(val_dataset.classes))
for _, label in val_dataset:
    val_class_counts[label] += 1

# Создать barplot
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Barplot для обучающего набора данных
sns.barplot(x=train_dataset.classes, y=train_class_counts, ax=ax[0])
ax[0].set_title('Train Dataset')
ax[0].set_xlabel('Class')
ax[0].set_ylabel('Number of Images')
ax[0].tick_params(axis='x', rotation=90)

# Barplot для валидационного набора данных
sns.barplot(x=val_dataset.classes, y=val_class_counts, ax=ax[1])
ax[1].set_title('Validation Dataset')
ax[1].set_xlabel('Class')
ax[1].set_ylabel('Number of Images')
ax[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# Пример фоток после нормализации:

# %%
# Функция для отображения изображений из батча с метками классов
def show_images(images, labels, denormalize=False):
    if denormalize:
        # Обратное преобразование для нормализации
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        images = images.numpy().transpose((0, 2, 3, 1))
        images = std * images + mean
        images = np.clip(images, 0, 1)
    else:
        images = images.numpy().transpose((0, 2, 3, 1))

    fig, axes = plt.subplots(4, 4, figsize=(7, 7))
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i])
        ax.set_title(f"Class: {classes_list[labels[i]]}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# Получение первого батча из тренировочного загрузчика данных
images, labels = next(iter(train_loader))

# Отображение изображений с восстановлением цветов и метками классов
print("Images with class labels:")
show_images(images, labels, denormalize=True)
# Out:
# Images with class labels:

# %% [markdown]
# Сколько в одной эпохе проходов по батчам:

# %%
len(train_loader), len(val_loader)
# Out:
# (41, 11)

# %%
img, label = next(iter(train_loader))

# %%
label
# Out:
# tensor([ 5,  8, 11,  8,  8,  5,  5, 12,  4, 10,  4, 13, 11,  9, 10,  6,  8,  2,
#          2, 10,  0,  7,  0,  5, 11, 12,  5,  5,  2, 12,  9,  4,  0,  6,  2,  0,
#          4, 10, 12, 10,  1,  9,  7, 13,  4, 13,  6, 10,  8,  2,  0,  1,  9,  2,
#          0,  7,  0,  2,  3,  4,  5,  3, 11,  4])

# %% [markdown]
# Пример данных в датасете и даталоадере:

# %%
train_dataset[0]
# Out:
# (tensor([[[ 1.8893,  1.9064,  1.9064,  ...,  1.6324,  1.3927,  1.2557],
#           [ 1.9064,  1.9407,  1.9578,  ...,  1.1187,  1.1529,  1.2043],
#           [ 1.9235,  1.9749,  1.9920,  ...,  0.3481,  0.5022,  0.5878],
#           ...,
#           [-1.8268, -1.8268, -1.8268,  ..., -1.7754, -1.6555, -1.3987],
#           [-1.8097, -1.8097, -1.8097,  ..., -1.7925, -1.6727, -1.6727],
#           [-1.8097, -1.8097, -1.8097,  ..., -1.7754, -1.8268, -1.7925]],
#
#          [[ 1.3256,  1.3606,  1.3957,  ...,  1.3431,  1.5882,  1.7108],
#           [ 1.3431,  1.3957,  1.4482,  ...,  1.0105,  1.3957,  1.6583],
#           [ 1.3606,  1.4307,  1.4832,  ...,  0.4503,  0.7654,  0.9405],
#           ...,
#           [-1.7381, -1.7381, -1.7381,  ..., -1.6856, -1.5280, -1.2654],
#           [-1.7206, -1.7206, -1.7206,  ..., -1.7206, -1.5630, -1.5280],
#           [-1.7206, -1.7206, -1.7206,  ..., -1.7031, -1.7031, -1.6331]],
#
#          [[ 1.2631,  1.2805,  1.3154,  ...,  1.4025,  1.5420,  1.5942],
#           [ 1.2805,  1.3328,  1.3677,  ...,  1.0191,  1.3328,  1.5420],
#           [ 1.2980,  1.3677,  1.4025,  ...,  0.3916,  0.7054,  0.8797],
#           ...,
#           [-1.5430, -1.5430, -1.5430,  ..., -1.6302, -1.4907, -1.2293],
#           [-1.5256, -1.5256, -1.5256,  ..., -1.6999, -1.5430, -1.5256],
#           [-1.5256, -1.5256, -1.5256,  ..., -1.6999, -1.6999, -1.6476]]]),
#  0)

# %%
next(iter(train_loader))
# Out:
# [tensor([[[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            ...,
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489]],
#
#           [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            ...,
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286]],
#
#           [[ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            ...,
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.0494, -2.0665, -2.0665,  ..., -2.0494, -2.0494, -2.0494],
#            [-2.0494, -2.0665, -2.0665,  ..., -2.0323, -2.0323, -2.0323],
#            [-2.0494, -2.0665, -2.0665,  ..., -2.0152, -2.0152, -2.0152],
#            ...,
#            [-1.9638, -1.9980, -1.9980,  ..., -1.4500, -1.4500, -1.4672],
#            [-1.9980, -2.0152, -2.0152,  ..., -1.4500, -1.4672, -1.4843],
#            [-2.0323, -2.0323, -2.0323,  ..., -1.4672, -1.5014, -1.5185]],
#
#           [[-1.9832, -2.0007, -2.0007,  ..., -1.7731, -1.7731, -1.7556],
#            [-1.9832, -2.0007, -2.0007,  ..., -1.7731, -1.7731, -1.7731],
#            [-1.9832, -2.0007, -2.0007,  ..., -1.7906, -1.7906, -1.7906],
#            ...,
#            [-1.3704, -1.3704, -1.3529,  ..., -1.5105, -1.5105, -1.5280],
#            [-1.3704, -1.3529, -1.3354,  ..., -1.5105, -1.5280, -1.5455],
#            [-1.3529, -1.3354, -1.3179,  ..., -1.5280, -1.5630, -1.5805]],
#
#           [[-1.6476, -1.6650, -1.6650,  ..., -1.1944, -1.2293, -1.2467],
#            [-1.6476, -1.6650, -1.6650,  ..., -1.1944, -1.2119, -1.2467],
#            [-1.6476, -1.6650, -1.6650,  ..., -1.1944, -1.1944, -1.2119],
#            ...,
#            [-0.6541, -0.6541, -0.6367,  ..., -1.4036, -1.4036, -1.4210],
#            [-0.6541, -0.6541, -0.6367,  ..., -1.4036, -1.4210, -1.4384],
#            [-0.6541, -0.6541, -0.6367,  ..., -1.4210, -1.4559, -1.4733]]],
#
#
#          ...,
#
#
#          [[[ 0.2111,  0.2282,  0.2453,  ...,  0.8276,  0.8276,  0.8447],
#            [ 0.2282,  0.2282,  0.2453,  ...,  0.8276,  0.8276,  0.8447],
#            [ 0.2282,  0.2282,  0.2453,  ...,  0.8276,  0.8104,  0.8276],
#            ...,
#            [-1.2617, -1.3130, -1.1418,  ..., -0.1657,  0.0056,  0.1939],
#            [-1.2959, -1.2788, -1.1932,  ..., -0.2171, -0.0287,  0.5193],
#            [-1.2788, -1.3130, -1.3815,  ..., -0.1143,  0.4337,  0.5707]],
#
#           [[ 0.1877,  0.2052,  0.2227,  ...,  0.7654,  0.7654,  0.7829],
#            [ 0.2052,  0.2052,  0.2227,  ...,  0.7654,  0.7654,  0.7829],
#            [ 0.2052,  0.2052,  0.2227,  ...,  0.7654,  0.7829,  0.8004],
#            ...,
#            [-1.2129, -1.2654, -1.0903,  ..., -0.5301, -0.3550, -0.1800],
#            [-1.2654, -1.2304, -1.1604,  ..., -0.6352, -0.4076,  0.1176],
#            [-1.2479, -1.2829, -1.3529,  ..., -0.5301,  0.0126,  0.1702]],
#
#           [[ 0.4265,  0.4439,  0.4614,  ...,  0.9842,  0.9842,  1.0017],
#            [ 0.4439,  0.4439,  0.4614,  ...,  1.0017,  1.0017,  1.0191],
#            [ 0.4439,  0.4439,  0.4614,  ...,  1.0191,  1.0191,  1.0365],
#            ...,
#            [-1.2641, -1.3164, -1.1073,  ..., -1.2990, -0.9504, -0.6367],
#            [-1.2641, -1.2293, -1.1073,  ..., -1.3687, -0.9504, -0.2184],
#            [-1.2119, -1.2293, -1.2816,  ..., -1.2293, -0.4450, -0.1138]]],
#
#
#          [[[ 2.0605,  2.0605,  2.0605,  ...,  2.1119,  2.1119,  2.1119],
#            [ 2.0605,  2.0605,  2.0605,  ...,  2.1119,  2.1119,  2.1119],
#            [ 2.0605,  2.0605,  2.0605,  ...,  2.1119,  2.1119,  2.1119],
#            ...,
#            [ 2.0605,  2.0605,  2.0605,  ...,  2.0605,  2.0605,  2.0605],
#            [ 2.0605,  2.0605,  2.0605,  ...,  2.0605,  2.0605,  2.0605],
#            [ 2.0605,  2.0605,  2.0605,  ...,  2.0605,  2.0605,  2.0605]],
#
#           [[ 2.2360,  2.2360,  2.2360,  ...,  2.2885,  2.2885,  2.2885],
#            [ 2.2360,  2.2360,  2.2360,  ...,  2.2885,  2.2885,  2.2885],
#            [ 2.2360,  2.2360,  2.2360,  ...,  2.2885,  2.2885,  2.2885],
#            ...,
#            [ 2.2360,  2.2360,  2.2360,  ...,  2.2360,  2.2360,  2.2360],
#            [ 2.2360,  2.2360,  2.2360,  ...,  2.2360,  2.2360,  2.2360],
#            [ 2.2360,  2.2360,  2.2360,  ...,  2.2360,  2.2360,  2.2360]],
#
#           [[ 2.4483,  2.4483,  2.4483,  ...,  2.5006,  2.5006,  2.5006],
#            [ 2.4483,  2.4483,  2.4483,  ...,  2.5006,  2.5006,  2.5006],
#            [ 2.4483,  2.4483,  2.4483,  ...,  2.5006,  2.5006,  2.5006],
#            ...,
#            [ 2.4483,  2.4483,  2.4483,  ...,  2.4483,  2.4483,  2.4483],
#            [ 2.4483,  2.4483,  2.4483,  ...,  2.4483,  2.4483,  2.4483],
#            [ 2.4483,  2.4483,  2.4483,  ...,  2.4483,  2.4483,  2.4483]]],
#
#
#          [[[ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            ...,
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489],
#            [ 2.2489,  2.2489,  2.2489,  ...,  2.2489,  2.2489,  2.2489]],
#
#           [[ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            ...,
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286],
#            [ 2.4286,  2.4286,  2.4286,  ...,  2.4286,  2.4286,  2.4286]],
#
#           [[ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            ...,
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400],
#            [ 2.6400,  2.6400,  2.6400,  ...,  2.6400,  2.6400,  2.6400]]]]),
#  tensor([12,  7,  8, 12,  5,  3,  1,  1,  8, 11,  4, 13, 12,  4,  5,  2,  1,  4,
#          10, 12, 12,  8, 12, 13,  6,  0,  7, 13,  1,  4,  5, 13, 11,  0,  7,  8,
#           7, 12,  4,  0,  6,  6, 11, 12,  9,  5, 12,  0,  1, 12,  2,  5, 11, 11,
#           8,  8, 10,  8,  8,  5,  2,  0, 10,  9])]

# %% [markdown]
# ## Загрузим предобученную модель
#
# https://pytorch.org/vision/main/models.html
#
# https://huggingface.co/timm

# %%
from torchvision.models import resnet18, ResNet18_Weights

# Загрузим предварительно обученную модель ResNet18
model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 203MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# Для использования предобученной модели нам нужно поменять последний слой, чтобы он выдавал нужное кол-во классов (в данном датасете 12). Это можно сделать двумя способами:
# 1. Добавить новый полносвязный слой, в данной модели это будет слой с 1000 входными нейронами и 12 выходными.
# 2. Заменить последний слой, тогда получится слой с 512 входными нейронами и 12 выходными.

# %%
# Первый подход
num_classes = len(classes_list)
model_seq = torch.nn.Sequential(model, nn.ReLU(), nn.Linear(model.fc.out_features, num_classes))
model_seq
# Out:
# Sequential(
#   (0): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=1000, bias=True)
#   )
#   (1): ReLU()
#   (2): Linear(in_features=1000, out_features=14, bias=True)
# )

# %%
model.fc = nn.Linear(model.fc.in_features, num_classes)

# %%
model.fc
# Out:
# Linear(in_features=512, out_features=14, bias=True)

# %%
# Заменим последний слой (fully connected) так, чтобы количество выходных каналов соответствовало N классам
num_classes = len(classes_list)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=14, bias=True)
# )

# %%
model.eval()
model.to(device)
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(val_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
val_accuracy = correct / total
print(val_accuracy)
# Out:
# 100%|██████████| 11/11 [00:02<00:00,  3.92it/s]
# 0.06636500754147813

# %% [markdown]
# ## Использование предобученных моделей
#
# | Тип использования                | Fine-Tuning                                                                 | Transfer Learning                                                             |
# |-----------------------|-----------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | Задача             | Адаптировать веса модели к новой задаче                            | Переиспользовать знания из весов модели для решения новой задачи |
# | Подход к обучению      | Обучаем все слои модели                                       | Часть первых слоев замораживаются, и обучаются только последние слои |
# | Данные       | Обычно необходимо большое кол-во данных                     | Требуется не так много данных  |
# | Когда использовать              | Когда есть много данных и имеются вычислительные ресурсы | Когда мало данных или не очень по вычислительным ресурсам. Также имеет смысл если новая задача похожа на задачу предобученной модели |
# | Метрики            | Обычно лучше метрики                    | Обычно хуже метрики |

# %% [markdown]
# ## Модель для fine-tune`а

# %%
class ResNet18ForFineTune(nn.Module):

    def __init__(self):
        super().__init__()
        self.resnet = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, num_classes)

    def forward(self, x):
        return self.resnet(x)

model = ResNet18ForFineTune()

# %%
# Валидация модели до обучения:

model.eval()
model.to(device)
correct = 0
total = 0
with torch.no_grad():
    for images, labels in tqdm(val_loader):
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
val_accuracy = correct / total
print(val_accuracy)
# Out:
# 100%|██████████| 11/11 [00:01<00:00,  6.31it/s]
# 0.11764705882352941

# %% [markdown]
# # Обучение сети:

# %%
def train(model, loss_fn, optimizer, dataloader):
    model.train()
    train_loss = 0
    train_acc = 0
    it_count = len(dataloader)
    with tqdm(total=it_count) as pbar:
        for batch, (images, labels) in enumerate(dataloader):
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            train_loss += loss.item()
            train_acc += (outputs.argmax(dim=1) == labels).float().mean().item()

            # Backprpagation and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            pbar.update(1)

            if batch % (it_count // 3) == 0:
                pbar.set_description(f"Train_loss: {round(train_loss / (batch + 1), 3)}" + f" Train_acc: {round(train_acc / (batch + 1), 3)}")

    return train_loss / it_count, train_acc / it_count


def test(model, loss_fn, dataloader):
    model.eval()
    test_loss = 0
    test_acc = 0
    it_count = len(dataloader)
    with tqdm(total=it_count) as pbar:
        with torch.no_grad():
            for batch, (images, labels) in enumerate(dataloader):
                images, labels = images.to(device), labels.to(device)

                # Forward pass
                outputs = model(images)
                loss = loss_fn(outputs, labels)
                test_loss += loss.item()
                test_acc += (outputs.argmax(dim=1) == labels).float().mean().item()

                pbar.update(1)

                if batch % (it_count // 3) == 0:
                    pbar.set_description(f"Test_loss: {round(test_loss / (batch + 1), 3)}" + f" Test_acc: {round(test_acc / (batch + 1), 3)}")

    return test_loss / it_count, test_acc / it_count


def train_test_loop(model, loss_fn, optimizer, num_epochs):
    train_losses, test_losses = [], []
    train_accs, test_accs = [], []
    best_val_accuracy = 0

    model.to(device)
    for epoch in range(num_epochs):
        print(f"EPOCH {epoch}" + '-' * 100)
        loss, acc = train(model, loss_fn, optimizer, train_loader)
        train_losses.append(loss)
        train_accs.append(acc)

        loss, acc = test(model, loss_fn, val_loader)
        test_losses.append(loss)
        test_accs.append(acc)

        if acc > best_val_accuracy:
            best_val_accuracy = acc
            torch.save(model.state_dict(), 'best_model.pth')
            print('Saved best model!')

    # Сохранение последней актуальной модели
    torch.save(model.state_dict(), 'last_model.pth')
    print()

    return train_losses, test_losses, train_accs, test_accs

# %%
num_epochs = 15
model = ResNet18ForFineTune()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
loop_info_finetune = train_test_loop(model, criterion, optimizer, num_epochs)
# Out:
# EPOCH 0----------------------------------------------------------------------------------------------------
# Train_loss: 1.501 Train_acc: 0.566: 100%|██████████| 41/41 [00:08<00:00,  4.81it/s]
# Test_loss: 0.855 Test_acc: 0.752: 100%|██████████| 11/11 [00:02<00:00,  5.38it/s]
# Saved best model!
# EPOCH 1----------------------------------------------------------------------------------------------------
# Train_loss: 0.594 Train_acc: 0.837: 100%|██████████| 41/41 [00:07<00:00,  5.19it/s]
# Test_loss: 0.804 Test_acc: 0.769: 100%|██████████| 11/11 [00:01<00:00,  6.72it/s]
# Saved best model!
# EPOCH 2----------------------------------------------------------------------------------------------------
# Train_loss: 0.308 Train_acc: 0.925: 100%|██████████| 41/41 [00:07<00:00,  5.37it/s]
# Test_loss: 0.769 Test_acc: 0.777: 100%|██████████| 11/11 [00:01<00:00,  5.50it/s]
# Saved best model!
# EPOCH 3----------------------------------------------------------------------------------------------------
# Train_loss: 0.192 Train_acc: 0.952: 100%|██████████| 41/41 [00:07<00:00,  5.40it/s]
# Test_loss: 0.814 Test_acc: 0.77: 100%|██████████| 11/11 [00:01<00:00,  6.67it/s]
# EPOCH 4----------------------------------------------------------------------------------------------------
# Train_loss: 0.145 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  4.63it/s]
# Test_loss: 0.834 Test_acc: 0.786: 100%|██████████| 11/11 [00:02<00:00,  4.14it/s]
# Saved best model!
# EPOCH 5----------------------------------------------------------------------------------------------------
# Train_loss: 0.115 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  5.09it/s]
# Test_loss: 0.856 Test_acc: 0.783: 100%|██████████| 11/11 [00:01<00:00,  6.83it/s]
# EPOCH 6----------------------------------------------------------------------------------------------------
# Train_loss: 0.109 Train_acc: 0.961: 100%|██████████| 41/41 [00:08<00:00,  5.02it/s]
# Test_loss: 0.888 Test_acc: 0.778: 100%|██████████| 11/11 [00:01<00:00,  6.86it/s]
# EPOCH 7----------------------------------------------------------------------------------------------------
# Train_loss: 0.098 Train_acc: 0.961: 100%|██████████| 41/41 [00:08<00:00,  5.01it/s]
# Test_loss: 0.878 Test_acc: 0.781: 100%|██████████| 11/11 [00:01<00:00,  6.73it/s]
# EPOCH 8----------------------------------------------------------------------------------------------------
# Train_loss: 0.091 Train_acc: 0.961: 100%|██████████| 41/41 [00:08<00:00,  5.12it/s]
# Test_loss: 0.9 Test_acc: 0.777: 100%|██████████| 11/11 [00:02<00:00,  5.36it/s]
# EPOCH 9----------------------------------------------------------------------------------------------------
# Train_loss: 0.085 Train_acc: 0.964: 100%|██████████| 41/41 [00:08<00:00,  5.02it/s]
# Test_loss: 0.925 Test_acc: 0.78: 100%|██████████| 11/11 [00:01<00:00,  6.57it/s]
# EPOCH 10----------------------------------------------------------------------------------------------------
# Train_loss: 0.085 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  4.61it/s]
# Test_loss: 0.913 Test_acc: 0.775: 100%|██████████| 11/11 [00:01<00:00,  5.89it/s]
# EPOCH 11----------------------------------------------------------------------------------------------------
# Train_loss: 0.075 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  4.74it/s]
# Test_loss: 0.91 Test_acc: 0.78: 100%|██████████| 11/11 [00:01<00:00,  6.76it/s]
# EPOCH 12----------------------------------------------------------------------------------------------------
# Train_loss: 0.076 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  4.84it/s]
# Test_loss: 0.951 Test_acc: 0.77: 100%|██████████| 11/11 [00:01<00:00,  6.78it/s]
# EPOCH 13----------------------------------------------------------------------------------------------------
# Train_loss: 0.073 Train_acc: 0.963: 100%|██████████| 41/41 [00:08<00:00,  4.88it/s]
# Test_loss: 0.951 Test_acc: 0.784: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# EPOCH 14----------------------------------------------------------------------------------------------------
# Train_loss: 0.069 Train_acc: 0.964: 100%|██████████| 41/41 [00:08<00:00,  5.00it/s]
# Test_loss: 0.925 Test_acc: 0.78: 100%|██████████| 11/11 [00:01<00:00,  5.89it/s]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), loop_info_finetune[0], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[1], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), loop_info_finetune[2], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[3], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epoch')
plt.legend()

plt.show()

# %%
# Получение метрик качества для текущих весов модели
def evaluate_model(model, dataloader):
    model.eval()
    y_true = []
    y_pred = []
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred)
    accuracy = np.sum(np.diag(cm)) / np.sum(cm)
    # Вычисление взвешенной F1-меры для текущей модели
    weighted_f1 = f1_score(y_true, y_pred, average='weighted')
    return cm, report, accuracy, weighted_f1

# Функция для построения графика матрицы ошибок
def plot_confusion_matrix(cm, classes):
    with plt.style.context('default'):
        plt.figure(figsize=(5, 4))
        sns.set_theme(font_scale=1.0)
        sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', cbar=False,
                    xticklabels=classes, yticklabels=classes)
        plt.xlabel('Predicted labels')
        plt.ylabel('True labels')
        plt.title('Confusion Matrix')
        plt.show()

# %%
# Загрузка весов модели
model.load_state_dict(torch.load('best_model.pth'))
model.to(device)

# Оценка модели и построение матрицы ошибок
cm, report, accuracy_1, weighted_f1_1 = evaluate_model(model, val_loader)
print("Metrics for current model:")
print(report)
print(f'Test Accuracy: {accuracy_1:.4f}')
plot_confusion_matrix(cm, classes=list(range(len(classes_list))))
# Out:
# Metrics for current model:
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        60
#            1       0.60      0.82      0.70        57
#            2       0.66      0.66      0.66        29
#            3       0.71      0.53      0.61        32
#            4       0.90      0.70      0.79        53
#            5       0.88      0.87      0.88        53
#            6       0.79      0.85      0.82        54
#            7       0.89      0.77      0.82        43
#            8       0.77      0.92      0.84        52
#            9       0.70      0.71      0.71        49
#           10       0.87      0.81      0.84        42
#           11       0.86      0.80      0.83        46
#           12       0.93      0.87      0.90        60
#           13       0.94      0.88      0.91        33
#
#     accuracy                           0.79       663
#    macro avg       0.80      0.78      0.79       663
# weighted avg       0.80      0.79      0.79       663
#
# Test Accuracy: 0.7888

# %% [markdown]
# ## Модель для transfer learning`а

# %%
class ResNet18ForTransferLearning(nn.Module):

    def __init__(self):
        super().__init__()
        self.resnet = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        for param in self.resnet.parameters():
            param.requires_grad = False

        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, num_classes)
        self.resnet.fc.requires_grad_(True)

    def forward(self, x):
        return self.resnet(x)

model = ResNet18ForTransferLearning()

# %%
num_epochs = 15
model = ResNet18ForTransferLearning()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
loop_info_finetune = train_test_loop(model, criterion, optimizer, num_epochs)
# Out:
# EPOCH 0----------------------------------------------------------------------------------------------------
# Train_loss: 2.068 Train_acc: 0.406: 100%|██████████| 41/41 [00:06<00:00,  6.18it/s]
# Test_loss: 1.481 Test_acc: 0.655: 100%|██████████| 11/11 [00:01<00:00,  5.93it/s]
# Saved best model!
# EPOCH 1----------------------------------------------------------------------------------------------------
# Train_loss: 1.311 Train_acc: 0.679: 100%|██████████| 41/41 [00:06<00:00,  5.93it/s]
# Test_loss: 1.16 Test_acc: 0.709: 100%|██████████| 11/11 [00:01<00:00,  6.84it/s]
# Saved best model!
# EPOCH 2----------------------------------------------------------------------------------------------------
# Train_loss: 1.086 Train_acc: 0.713: 100%|██████████| 41/41 [00:07<00:00,  5.72it/s]
# Test_loss: 1.056 Test_acc: 0.719: 100%|██████████| 11/11 [00:01<00:00,  6.76it/s]
# EPOCH 3----------------------------------------------------------------------------------------------------
# Train_loss: 0.985 Train_acc: 0.727: 100%|██████████| 41/41 [00:07<00:00,  5.58it/s]
# Test_loss: 0.962 Test_acc: 0.747: 100%|██████████| 11/11 [00:02<00:00,  4.82it/s]
# Saved best model!
# EPOCH 4----------------------------------------------------------------------------------------------------
# Train_loss: 0.908 Train_acc: 0.751: 100%|██████████| 41/41 [00:06<00:00,  6.08it/s]
# Test_loss: 0.944 Test_acc: 0.753: 100%|██████████| 11/11 [00:01<00:00,  6.62it/s]
# Saved best model!
# EPOCH 5----------------------------------------------------------------------------------------------------
# Train_loss: 0.856 Train_acc: 0.765: 100%|██████████| 41/41 [00:07<00:00,  5.66it/s]
# Test_loss: 0.918 Test_acc: 0.738: 100%|██████████| 11/11 [00:01<00:00,  6.80it/s]
# EPOCH 6----------------------------------------------------------------------------------------------------
# Train_loss: 0.816 Train_acc: 0.779: 100%|██████████| 41/41 [00:07<00:00,  5.75it/s]
# Test_loss: 0.907 Test_acc: 0.742: 100%|██████████| 11/11 [00:01<00:00,  6.72it/s]
# EPOCH 7----------------------------------------------------------------------------------------------------
# Train_loss: 0.78 Train_acc: 0.788: 100%|██████████| 41/41 [00:06<00:00,  6.16it/s]
# Test_loss: 0.882 Test_acc: 0.758: 100%|██████████| 11/11 [00:01<00:00,  5.69it/s]
# EPOCH 8----------------------------------------------------------------------------------------------------
# Train_loss: 0.753 Train_acc: 0.789: 100%|██████████| 41/41 [00:06<00:00,  5.94it/s]
# Test_loss: 0.886 Test_acc: 0.753: 100%|██████████| 11/11 [00:01<00:00,  6.76it/s]
# EPOCH 9----------------------------------------------------------------------------------------------------
# Train_loss: 0.731 Train_acc: 0.794: 100%|██████████| 41/41 [00:07<00:00,  5.64it/s]
# Test_loss: 0.891 Test_acc: 0.747: 100%|██████████| 11/11 [00:01<00:00,  6.67it/s]
# EPOCH 10----------------------------------------------------------------------------------------------------
# Train_loss: 0.715 Train_acc: 0.801: 100%|██████████| 41/41 [00:07<00:00,  5.83it/s]
# Test_loss: 0.882 Test_acc: 0.75: 100%|██████████| 11/11 [00:01<00:00,  5.99it/s]
# EPOCH 11----------------------------------------------------------------------------------------------------
# Train_loss: 0.691 Train_acc: 0.802: 100%|██████████| 41/41 [00:06<00:00,  6.12it/s]
# Test_loss: 0.88 Test_acc: 0.744: 100%|██████████| 11/11 [00:01<00:00,  6.74it/s]
# EPOCH 12----------------------------------------------------------------------------------------------------
# Train_loss: 0.687 Train_acc: 0.8: 100%|██████████| 41/41 [00:09<00:00,  4.44it/s]
# Test_loss: 0.908 Test_acc: 0.73: 100%|██████████| 11/11 [00:01<00:00,  6.71it/s]
# EPOCH 13----------------------------------------------------------------------------------------------------
# Train_loss: 0.67 Train_acc: 0.807: 100%|██████████| 41/41 [00:07<00:00,  5.69it/s]
# Test_loss: 0.897 Test_acc: 0.745: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# EPOCH 14----------------------------------------------------------------------------------------------------
# Train_loss: 0.651 Train_acc: 0.822: 100%|██████████| 41/41 [00:07<00:00,  5.68it/s]
# Test_loss: 0.89 Test_acc: 0.733: 100%|██████████| 11/11 [00:01<00:00,  6.50it/s]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), loop_info_finetune[0], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[1], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), loop_info_finetune[2], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[3], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epoch')
plt.legend()

plt.show()

# %%
# Загрузка весов модели
model.load_state_dict(torch.load('best_model.pth'))
model.to(device)

# Оценка модели и построение матрицы ошибок
cm, report, accuracy_1, weighted_f1_1 = evaluate_model(model, val_loader)
print("Metrics for current model:")
print(report)
print(f'Test Accuracy: {accuracy_1:.4f}')
plot_confusion_matrix(cm, classes=list(range(len(classes_list))))
# Out:
# Metrics for current model:
#               precision    recall  f1-score   support
#
#            0       0.62      0.67      0.65        60
#            1       0.57      0.74      0.64        57
#            2       0.56      0.62      0.59        29
#            3       0.62      0.41      0.49        32
#            4       0.81      0.72      0.76        53
#            5       0.90      0.81      0.85        53
#            6       0.88      0.80      0.83        54
#            7       0.75      0.77      0.76        43
#            8       0.73      0.90      0.81        52
#            9       0.62      0.69      0.65        49
#           10       0.92      0.81      0.86        42
#           11       0.90      0.78      0.84        46
#           12       0.96      0.90      0.93        60
#           13       0.84      0.82      0.83        33
#
#     accuracy                           0.76       663
#    macro avg       0.76      0.75      0.75       663
# weighted avg       0.77      0.76      0.76       663
#
# Test Accuracy: 0.7572

# %% [markdown]
# # Добавим аугментаций

# %%
from torchvision.transforms import v2 as transforms

# %%
# Определим трансформации
train_transforms = transforms.Compose([
    transforms.Resize(235),
    transforms.RandomRotation((-3, 3)),
    transforms.CenterCrop(200),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.15, hue=0.15),
    transforms.RandomHorizontalFlip(0.5),
    transforms.ToDtype(torch.float, scale=True),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.Resize(235),
    transforms.CenterCrop(224),
    transforms.ToDtype(torch.float, scale=True),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# Создадим датасеты
train_dataset.transform = train_transforms
val_dataset.transform = val_transforms

# Создадим датагенераторы
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# Пример фоток после аугментации:

# %%
# Получение первого батча из тренировочного загрузчика данных
images, labels = next(iter(train_loader))

# Отображение изображений с восстановлением цветов
print("Images without normalization:")
show_images(images, labels, denormalize=True)
# Out:
# Images without normalization:

# %%
num_epochs = 15
model = ResNet18ForFineTune()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
loop_info_finetune = train_test_loop(model, criterion, optimizer, num_epochs)
# Out:
# EPOCH 0----------------------------------------------------------------------------------------------------
# Train_loss: 1.587 Train_acc: 0.538: 100%|██████████| 41/41 [00:22<00:00,  1.80it/s]
# Test_loss: 0.944 Test_acc: 0.741: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# Saved best model!
# EPOCH 1----------------------------------------------------------------------------------------------------
# Train_loss: 0.788 Train_acc: 0.789: 100%|██████████| 41/41 [00:21<00:00,  1.90it/s]
# Test_loss: 0.827 Test_acc: 0.775: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# Saved best model!
# EPOCH 2----------------------------------------------------------------------------------------------------
# Train_loss: 0.548 Train_acc: 0.853: 100%|██████████| 41/41 [00:21<00:00,  1.92it/s]
# Test_loss: 0.795 Test_acc: 0.777: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# Saved best model!
# EPOCH 3----------------------------------------------------------------------------------------------------
# Train_loss: 0.391 Train_acc: 0.901: 100%|██████████| 41/41 [00:21<00:00,  1.90it/s]
# Test_loss: 0.797 Test_acc: 0.777: 100%|██████████| 11/11 [00:01<00:00,  6.65it/s]
# EPOCH 4----------------------------------------------------------------------------------------------------
# Train_loss: 0.285 Train_acc: 0.927: 100%|██████████| 41/41 [00:22<00:00,  1.84it/s]
# Test_loss: 0.805 Test_acc: 0.778: 100%|██████████| 11/11 [00:01<00:00,  6.66it/s]
# Saved best model!
# EPOCH 5----------------------------------------------------------------------------------------------------
# Train_loss: 0.226 Train_acc: 0.939: 100%|██████████| 41/41 [00:21<00:00,  1.91it/s]
# Test_loss: 0.853 Test_acc: 0.772: 100%|██████████| 11/11 [00:01<00:00,  6.59it/s]
# EPOCH 6----------------------------------------------------------------------------------------------------
# Train_loss: 0.176 Train_acc: 0.955: 100%|██████████| 41/41 [00:21<00:00,  1.91it/s]
# Test_loss: 0.871 Test_acc: 0.761: 100%|██████████| 11/11 [00:01<00:00,  6.60it/s]
# EPOCH 7----------------------------------------------------------------------------------------------------
# Train_loss: 0.169 Train_acc: 0.959: 100%|██████████| 41/41 [00:21<00:00,  1.95it/s]
# Test_loss: 0.933 Test_acc: 0.759: 100%|██████████| 11/11 [00:02<00:00,  5.26it/s]
# EPOCH 8----------------------------------------------------------------------------------------------------
# Train_loss: 0.127 Train_acc: 0.961: 100%|██████████| 41/41 [00:20<00:00,  1.98it/s]
# Test_loss: 0.895 Test_acc: 0.767: 100%|██████████| 11/11 [00:01<00:00,  5.82it/s]
# EPOCH 9----------------------------------------------------------------------------------------------------
# Train_loss: 0.132 Train_acc: 0.964: 100%|██████████| 41/41 [00:21<00:00,  1.94it/s]
# Test_loss: 0.864 Test_acc: 0.773: 100%|██████████| 11/11 [00:01<00:00,  6.70it/s]
# EPOCH 10----------------------------------------------------------------------------------------------------
# Train_loss: 0.119 Train_acc: 0.961: 100%|██████████| 41/41 [00:21<00:00,  1.92it/s]
# Test_loss: 0.873 Test_acc: 0.775: 100%|██████████| 11/11 [00:01<00:00,  6.63it/s]
# EPOCH 11----------------------------------------------------------------------------------------------------
# Train_loss: 0.112 Train_acc: 0.966: 100%|██████████| 41/41 [00:21<00:00,  1.92it/s]
# Test_loss: 0.876 Test_acc: 0.772: 100%|██████████| 11/11 [00:01<00:00,  6.63it/s]
# EPOCH 12----------------------------------------------------------------------------------------------------
# Train_loss: 0.117 Train_acc: 0.964: 100%|██████████| 41/41 [00:21<00:00,  1.89it/s]
# Test_loss: 0.88 Test_acc: 0.769: 100%|██████████| 11/11 [00:01<00:00,  6.57it/s]
# EPOCH 13----------------------------------------------------------------------------------------------------
# Train_loss: 0.103 Train_acc: 0.963: 100%|██████████| 41/41 [00:22<00:00,  1.84it/s]
# Test_loss: 0.894 Test_acc: 0.759: 100%|██████████| 11/11 [00:01<00:00,  6.63it/s]
# EPOCH 14----------------------------------------------------------------------------------------------------
# Train_loss: 0.097 Train_acc: 0.967: 100%|██████████| 41/41 [00:21<00:00,  1.91it/s]
# Test_loss: 0.911 Test_acc: 0.772: 100%|██████████| 11/11 [00:01<00:00,  6.69it/s]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs+1), loop_info_finetune[0], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[1], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs+1), loop_info_finetune[2], label='Train')
plt.plot(range(1, num_epochs+1), loop_info_finetune[3], label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epoch')
plt.legend()

plt.show()

# %%
# Загрузка весов модели
model.load_state_dict(torch.load('best_model.pth'))
model.to(device)

# Оценка модели и построение матрицы ошибок
cm, report, accuracy_1, weighted_f1_1 = evaluate_model(model, val_loader)
print("Metrics for current model:")
print(report)
print(f'Test Accuracy: {accuracy_1:.4f}')
plot_confusion_matrix(cm, classes=list(range(len(classes_list))))
# Out:
# Metrics for current model:
#               precision    recall  f1-score   support
#
#            0       0.68      0.70      0.69        60
#            1       0.63      0.79      0.70        57
#            2       0.62      0.52      0.57        29
#            3       0.68      0.66      0.67        32
#            4       0.83      0.72      0.77        53
#            5       0.91      0.81      0.86        53
#            6       0.79      0.81      0.80        54
#            7       0.89      0.77      0.82        43
#            8       0.82      0.88      0.85        52
#            9       0.68      0.65      0.67        49
#           10       0.78      0.90      0.84        42
#           11       0.90      0.83      0.86        46
#           12       0.83      0.92      0.87        60
#           13       0.97      0.85      0.90        33
#
#     accuracy                           0.78       663
#    macro avg       0.79      0.77      0.78       663
# weighted avg       0.79      0.78      0.78       663
#
# Test Accuracy: 0.7813

# %% [markdown]
# ## Как написать кастомный лосс:

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    @torch.compile
    def forward(self, inputs, targets):
        ce_loss = torch.nn.functional.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return torch.mean(focal_loss)
        elif self.reduction == 'sum':
            return torch.sum(focal_loss)
        else:
            return focal_loss

# criterion = FocalLoss()

# %% [markdown]
# ---

# %% [markdown]
# # Инференс готовой модели

# %%
# Загрузим предварительно обученную модель ResNet18
model = ResNet18ForFineTune()
model.load_state_dict(torch.load('best_model.pth'))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.eval()

# Предобработка изображения
preprocess = transforms.Compose([
    transforms.Resize(235),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
# Загрузите изображение для инференса
image_path = 'test.png'  # Замените на путь к вашему изображению
image = Image.open(image_path).convert("RGB")  # <--- Приводим к RGB
image_tensor = preprocess(image)
image_tensor = image_tensor.unsqueeze(0).to(device)  # Добавляем размер батча

# Прогоните изображение через модель
with torch.no_grad():
    output = model(image_tensor)

# Примените softmax для получения вероятностей классов
probabilities = torch.nn.functional.softmax(output[0], dim=0).cpu()

# Отображение результатов
top_prob, top_class = torch.topk(probabilities, 1)
top_prob = top_prob.item()
top_class = top_class.item()

# Получить имя класса
class_name = train_dataset.classes[top_class]

# Отобразить изображение
plt.imshow(image)
plt.axis('off')
plt.title(f'Predicted: {class_name} ({top_prob*100:.2f}%)')
plt.show()

# %%
# Построить барплот
plt.figure(figsize=(10, 5))
bars = plt.bar(range(len(probabilities)), probabilities, color='blue')
plt.xlabel('Classes')
plt.ylabel('Probability')
plt.title('Class Probabilities')
plt.xticks(range(len(probabilities)), train_dataset.classes, rotation='vertical')

# Подсветить класс с наибольшей уверенностью
bars[top_class].set_color('red')

plt.tight_layout()
plt.show()

# %% [markdown]
# https://pytorch.org/tutorials/intermediate/torch_compile_tutorial.html
#
# https://pytorch.org/tutorials/advanced/cpp_export.html
#
# https://onnxruntime.ai/docs/get-started/with-cpp.html
#
# https://pytorch.org/tutorials/advanced/super_resolution_with_onnxruntime.html
#
# https://docs.nvidia.com/deeplearning/tensorrt/developer-guide/index.html
