# %% [markdown]
# <a href="https://colab.research.google.com/github/BardRimon/Study/blob/main/algorithms_and_data_structures/sem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# Алгоритм бабл

# %%
def select_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# %% [markdown]
# def

# %%
def shaker_sort(arr):
    bot = 1
    up = len(arr) - 1
    k = up
    while (bot < up):
        for i in range(up, bot, -1):
            if (arr[i - 1] > arr[i]):
                arr[i - 1], arr[i] = arr[i], arr[i - 1]
                k = i
        bot = k + 1
        for i in range(1, up + 1):
            if (arr[i - 1] > arr[i]):
                arr[i - 1], arr[i] = arr[i], arr[i - 1]
                k = i
        up = k - 1
    return arr

# %%
rng = np.random.RandomState()
n = 1000
s = range(2, n)
times_selsect = []
times_shake = []
for size in s:

  m = rng.randint(11, size=size)
  start_time = time.time()

  # algorithm
  ans = select_sort(m)

  end_time = time.time()

  execution_time = end_time - start_time
  times_selsect.append(execution_time)

for size in s:

  m = rng.randint(11, size=size)
  start_time = time.time()

  # algorithm
  ans = shaker_sort(m)

  end_time = time.time()

  execution_time = end_time - start_time
  times_shake.append(execution_time)

# %%
plt.plot(s, times_selsect, label='Select Sort') # добавили label для легенды
plt.plot(s, times_shake, color="red", label='Shaker Sort') # добавили label для легенды
plt.xlabel('Размер массива') # добавили подпись оси X
plt.ylabel('Время выполнения (сек)') # добавили подпись оси Y
plt.title('Сравнение времени выполнения алгоритмов сортировки') # добавили заголовок
plt.legend() # добавили легенду
plt.show()

# %%
plt.plot(times_selsect, s, label='Select Sort')
plt.plot(times_shake, s, color="red", label='Shaker Sort')
plt.xlabel('Время выполнения (сек)') # подпись оси X
plt.ylabel('Размер массива') # подпись оси Y
plt.title('Сравнение времени выполнения алгоритмов сортировки') # заголовок
plt.legend() # легенда
plt.show()
